# %% [markdown]
# # Instagram
# ---
# ## Listados de Entidades
#
# ### users **(ED)**
# - user_id **(PK)**
# - user_date
# - user_name
# - email  **(UQ)**
# - password
# - phone **(UQ)**
# - bio
# - web
# - avatar
# - birthdate
# - genre
# - country **(FK)**
#
# ### posts
# - post_id **(PK)**
# - post_date
# - plot
# - photo
# - user_id **(FK)**
#
# ### comments **(ED|EP)**
# - comment_id **(PK)**
# - comment_date
# - comment
# - post_id **(FK)**
# - user_id **(FK)**
#
# ### hearts **(ED|EP)**
# - heart_id **(PK)**
# - heart_date
# - post_id **(FK)**
# - user_id **(FK)**
# - comment_id  **(FK)**
#
# ### follows **(ED)**
# - follow_id **(PK)**
# - follow_date
# - follow_user **(FK)**
# - following_user **(FK)**
#
# ### countries **(EC)**
# - country_id  **(PK)**
# _ contry_name
#
# ---
# ### RELACIONES
# 1. Usuarios publican posts (_1 - M_)
# 1. Usuarios escriben comments  (_1 - M_)
# 1. Posts tienen comments (_1 - M_)
# 1. Los users otorgan hearts (_1 - M_)
# 1. Los posts tienen hearts (_1 - M_)
# 1. Los users tienen follows (_1 - M_)
# 1. Los users otorgan follows (_1 - M_)
# 1. Los users tienen un countries (_1 - M_)
# ---
# ### Modelo Relacional de la BD
#
# ![insta.drawio.png](attachment:insta.drawio.png)
#
# ---
# ### Reglas de Negocio
#
# ### users
# 1. Crear un usuers
# 1. Leer todos los usuers
# 1. Leer un user en particular
# 1. Validar un usuer
# 1. Actualizar datos del usuer
# 1. Actualizar password de usuer
# 1. Eliminar usuer
#
# ### post
# 1. Crear un post
# 1. Leer todos los post
# 1. Leer un post en particular
# 1. Actualizar el plot de un post
# 1. Eliminar un post
#
#
# ### comments
# 1. Crear un comment en un post
# 1. Leer todos los comments de un post
# 1. Leer un comment  en particular
# 1. Contar el número de comments de un post
# 1. Eliminar un comment
#
# ### hearts
# 1. Crear un heart en un post
# 1. Contar el número de hearts de un post
# 1. Eliminar heart de user en un post
#
# ### follows
# 1. Crear follow de un user
# 1. Contar el número de follows de un user
# 1. Contar el numero de following de un user
# 1. Eliminar follow de un user
#
# ### countries
# 1. Crear un country
# 1. Leer todos los countries
# 1. Leer un country en particular
# 1. Actualizar el plot de un country
# 1. Eliminar un country
