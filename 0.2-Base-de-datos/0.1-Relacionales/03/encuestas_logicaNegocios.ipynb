# %% [markdown]
# # Encuestas
#
# ## Listado de Entidades
#
# ### Encuentas **(ED)**
# - encuesta_id **(PK)**
# - nombre
# _ descripcion
# _ imagen
# _ fecha
# _ encuestados
#
# ### preguntas **(ED)**
# - pregunta_id **(PK)**
# _ encuesta_id **(FK)**
# - pregunta
#
# ### respuestas **(ED)**
# - respuesta_id **(PK)**
# - pregunta_id **(FK)**
# - respuesta
# - es_correcta
#
# ### encuestados **(ED)**
# - encuesta_id **(PK)**
# - nombre
# - apellidos
# - edad
# - email **(UQ)**
#
# ### resultados **(ED|EP)**
# - resultado_id **(PK)**
# - encutas_id **(fk)**
# - encuestado_id **(fk)**
# - preguntas
# - correctas
#
#
# ### Relaciones
# 1. Una encuesta tiene preguntas (1 - M)
# 1. Una pregunta tiene respuestas (1 - M)
# 1. Una encuesta tiene resultados (1-M)
# 1. Un encuestado tiene resultados (1-M )
#
# ### Modelo Relacional de Base de Datos sistema de encuestas
#
# ![Encuestas.drawio.png](attachment:Encuestas.drawio.png)
#
# ### Reglas de negocio
#
# ### Encuestas
# 1. Crear una encuesta
# 2. Leer todas encuesta
# 3. Leer una encuesta en particular
# 4. Actualizar una encuesta
# 5. eliminar una encuesta
# 6. Aumentar en +1 el valor del atributo encuestados cada que un encuesta completa la encuesta.
#
# ### Preguntas
# 1. Crear una pregunta
# 2. Leer todas las preguntas
# 3. Leer una pregunta en particular
# 4. Actualizar una pregunta
# 5. eliminar una pregunta
#
# ### Respuestas
# 1. Crear una respuesta
# 1. Leer todas las respuesta
# 3. Leer una respuesta en particular
# 4. Actualizar una respuesta
# 5. eliminar una respuesta
#
# ### Encuestados
# 1. Crear una encuestado
# 1. Leer todas los encuestados
# 3. Leer una encuestado en particular
# 4. Actualizar una encuestado
# 5. eliminar una encuestado
# 6. Antes de crear un encuestado en la entidad, verificar mediante su email que no exista.
#
# ### Resultados
# 1. Crear una resultado
# 1. Leer todas los resultados
# 3. Leer un resultado en particular
# 4. Actualizar un resultado
# 5. eliminar un resultado
# 6. Sacar el porcentaje de asertividad que tuvo en el encuestado al contestar la encuesta
