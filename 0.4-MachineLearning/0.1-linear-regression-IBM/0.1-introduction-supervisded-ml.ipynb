# %% [markdown]
# # Introduction to Supervised Machine Learning
#
# ### What is Machine Learning?
#
# Machine learning: is the process through which computers are said to "learn" and infer predictions from data.
#
# ### Machine learning in context: AI
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ### Model: A Learning Algorithm
#
# A **model** is a small thing that captures a larger thing.
#
# A good model omits unimportant details while retaining what's importatnt.
#
# ### Machine Learning in Our Daily Lives
#
# ![image-3.png](attachment:image-3.png)
#
# ### Fit Parameters Vs. Hyperparameters
#
# **ML Frameworks** (applies to Supervised Machine Learning Models)
# ![image-4.png](attachment:image-4.png)
#
# out framework estimates a relationship between the features and target:
#
# - Here, (The **fit parameters**) involve aspects of the model we estimate (fit) using the data.
# - To implement our approach, we make decisions regarding how to produce these estimates.
# - These decisions lead to **hyperparameters**, that are an important part of the machine learning workflow (though not explicit components of the model).
#
# ### Machine Learning Framework
#
# **ML Frameworks** (applies to every Supervised Machine Learning Models):
#
# ![image-5.png](attachment:image-5.png)
#
# Two main modeling approaches:
#
# - **Regression**: y is numeric.
#     - E.g.: stock price, box office revenue, location (x,y coordinates).
# - **Classification**: y is categorical.
#     - E.g.: face recognition customer churn, which word comes next.
#
#
# ### How does Machine Learning Work?
#
# **ML Framework** (applies to Supervised Machine Learning Models):
# ![image-6.png](attachment:image-6.png)
#
# ### Machine Learning Workflow
#
# Data Scientists train the model to find the best fit parameters given past experience.
#
# ![image-7.png](attachment:image-7.png)
#
#
# ### How Does Machine Learning Work?
#
# **ML Framework** (applies to Supervised Machine Learning Models):
#
# ![image-8.png](attachment:image-8.png)
#
#
# **Update rule**: Using features x and outcome y, choose parameters to minimize loss.
#
#
# ---
#
# ### Supervised Machine Learning Interpretation and Prediction
#
# > - Machine learning Objectives: Interpretation and Prediction
# > - Examples of Machine Learning applications
# > - The Machine Learning framework
#
# ### Interpretation and prediction
#
# **Interpretation**:
#
# - In some cases, the primary objectives is to train a model to find insights from the data.
#
# - In $y_p = f(x)$, the **interpretation approach** uses give us to insight into a system.
#
# ![image-9.png](attachment:image-9.png)
#
# **Prediction**:
# - In some cases, the primary objective is to make the best prediction.
#
# ![image-10.png](attachment:image-10.png)
#
# ---
#
# ### Example: Regression with Housing Data
#
# In this course, we will examine housing datasets.
#
# Here, our target is the **price** of housing, and our features include characteristics about the house and area.
#
# Suppose we fit our model $y_p = f(x)$, based on data on housing sales in Ames, lowa, and obtain estimates of parameters.
#
# These parameters represent coefficients relating the features $x$ with expected target values.
#
# We can **interpret** our results to learn about **feature importance**.
#
# ### Housing Data: Regression Interpretation
#
# Regression **Interpretation**:
#
# Examining results from regression of housing sales prices in Ames, lowa.
#
# Which features are most important.
#
# ![image-11.png](attachment:image-11.png)
#
# ### Example: Regression with Housing Data
#
# Here, our target is the **price** of housing, and our features include characteristics about the house and area.
#
# Suppose we fit our model $y_p = f(x)$, based on data on housing sales in Ames, lowa, and obtain estimates of parameters.
#
# Our primary aim may be **prediction**, in which case we are more focused on **generating** values for $y_p$ than in interpreting parameters.
#
# ### Housing Data: Regression Prediction
#
# **Prediction** using Regression Example:
#
# Use characteristics to predict unknown sale prices, focusing on how accurately we are able to predict.
#
# ---
# ![image-12.png](attachment:image-12.png)
#
# ### Classification Example: Customer Churn
#
# Customer churn occurs when a customer leaves a company.
#
# Data related to churn may include a target variable for whether or not the customer left, as well as information on customer characteristics.
#
# Here, we may be interested in both:
#     - **Interpretation**: Understanding factors that may lead to customers leaving.
#     - **Prediction**: estimating how long customers are likely to stay can help us understand how many we still need to support and how valueble they are to the company.
#
# ### Two common Approaches
#
# Interpretation and prediction in Supervised Machine Learning:
#
# - Majority of projects will can for a balance.
#
# - Interpretation can provide insights into improvements in prediction, and vice-versa.
#
# - Not all models will allow both: Supervised Machine Learning models provide varying levels of support for interpretation vs. prediction.
#
# ### ML Framework: Takeaways
#
# Machine Learning is the subset of AI that focuses on model building to support a goal of interpretation and/or prediction.
#
# ML algorithms;
#
# - Use past experience to build a model that is useful for future experience.
#
# - Follow a general form: $y_p = f(x)$
#
# ---
# ### Regression Vs. Classification Problems
#
# > - Types of supervised learning
# > - Examples of Regression and Classification problems
#
# ### Types of Supervised Learning
#
# ![image-13.png](attachment:image-13.png)
#
#
# ### Supervised Learning Overview
#
# ![image-14.png](attachment:image-14.png)
#
# ### Numeric Predicting: Movie Revenue
#
# ![image-15.png](attachment:image-15.png)
#
# ---
#
# ### Classification: Categorical Answers
#
# ![image-16.png](attachment:image-16.png)
#
# ### Classification: Predicting Spam Emails
#
# ![image-17.png](attachment:image-17.png)
#
# ---
#
# ### What is Needed for Classification?
#
# Model data with:
#
# - Features that can be quantified.
# - Labels that are known
# - Method to measure similarity
