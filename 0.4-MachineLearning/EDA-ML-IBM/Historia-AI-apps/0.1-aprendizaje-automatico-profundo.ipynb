# %% [markdown]
# # Machine Learning
#
# > "The study and construction of programs that are not explicitly programmed, but learn patterns as they are exposed to more data over time." - Arthur Samuel
#
# These programas learn from repeatedly seeing data, rather than being explicity programmed by hummas.
#
# ![alt text](image-3.png)
#
# ---
# ### Machine Learning Terminology
#
# ![image.png](attachment:image.png)
#
# ---
# ### Two main types of Machine Learning
#
# ![image-2.png](attachment:image-2.png)
#
# ---
# ### Machine Learning Example
#
# - Suppose you wanted to identify fraudulent card transactions.
# - You could define features to be:
#     - Transaction time
#     - Transaction amount
#     - Transaction location
#     - Category of purchase
#
# - The algorithm could learn what feature combination suggest unusual activity.
#
# ---
# ### Machine Learning Limitations
#
# ![image-3.png](attachment:image-3.png)
#
# ---
# ### Deep Learning
# ![image-4.png](attachment:image-4.png)
#
# ---
# ### Deep Learning Example
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
