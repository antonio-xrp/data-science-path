# %% [markdown]
# # Aprendizaje de máquina

# %% [markdown]
# **El Machine Learning (aprendizaje automático)** es una rama de la inteligencia artificial que se centra en el desarrollo de algoritmos y modelos que permiten a las computadoras aprender y hacer predicciones o tomar decisiones basadas en datos. En lugar de ser programadas explícitamente para realizar una tarea, las máquinas utilizan patrones y relaciones en los datos para mejorar su rendimiento con el tiempo.
#
# ### Tipos de Machine Learning:
# - **Aprendizaje supervisado:** El modelo se entrena con datos etiquetados, donde la salida esperada es conocida.
#
# Algunos modelos relacionados con el aprendizaje supervisado son:
# 1. Regresión lineal
# 2. Regresión logística
# 3. Máquinas de Soporte Vectorial (SVM)
# 4. Árboles de decisión
# 5. Bosques Aleatorios (Random Forests)
# 6. K-vecinos más cercanos (K-Nearest Neighbors KNN)
# 7. Redes neuronales artificiales (ANN)
#
# ![image.png](attachment:image.png)
#
# - **Aprendizaje no supervisado:** El modelo busca patrones en datos no etiquetados, sin saber de antemano cuál debe ser la salida.(clustering)
#
# Algunos modelos relacionados con el aprendizaje no supervisado son.
# 1. Clustering (Agrupamiento):
#     - K-means
#     - clustering jerarquico
# 2. Modelos de mezcla gaussiana (GMM)
# 3. Análisis de componentes principales (PCA)
# 4. Redes neuronales competitivas
# 5. Mapas Autoorganizados
#
#
# ![image-2.png](attachment:image-2.png)
#
# - **Aprendizaje por refuerzo:** El modelo aprende mediante la interacción con un entorno y recibe recompensas o castigos según sus acciones.
