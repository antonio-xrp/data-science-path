# %% [markdown]
# # classification models
#
# ### Classification problems
# > - Types of Supervised Learning (Regression and Classification)
# > - What is Needed for classification
# > - Overview of models commonly used for classification
#
# ### Types of Supervised Learning
#
#  ![image.png](attachment:image.png)
#
#  ### What is classification
#
#  A flower is a customer most likely to purchase on similarity to previous purchase?
#
#  ![image-2.png](attachment:image-2.png)
#
#  ### What is needed for classification?
#
#  - Model data with:
#     - Features that can be quantified
#     - Labels that are known
#
# - Method to measure similiraty
#
# ### Modeling Classification:
# Examples of models used for Supervised Learning: Classification:
# - Logistic Regression
# _ K-Nearest Neighbors
# - Support Vector Machine
# - Neural Networks
# - Decision Tree
# - Random Forest
# - Boosting
# - Ensamble Models
#
# Each of these models can be used for both regression and classification.
# ---
#
# ### Ligistic Regression
#
# > - Introduction to Logistic Regression
# > - Linear Regression vs. Logistic Regression
# > - Using Logistic Regression for classification
#
# ---
#
# ### Introduction to Logistic Regression
#
#
# ![image-4.png](attachment:image-4.png)
#
# ---
#
# ### Introducing the sigmoid function
#
# ![image-3.png](attachment:image-3.png)
#
# ### Linear Regression for classification?
#
# ![image-5.png](attachment:image-5.png)
#
# ### Logistic Vs . Linear Regression
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ### Classification with Logistic regression
#
# ![image-8.png](attachment:image-8.png)
#
# ---
# ### Logistic Regression with Multi-classes
#
# ![image-9.png](attachment:image-9.png)
#
# ### Multiple classes: One vs All
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ### Multiclass Decision Boundary
#
# ![image-12.png](attachment:image-12.png)
#
# ---
#
# ### Implementing Logistic Regression Models
#
# The syntax
#
# ```python
# # Import the class containing the classification method
# from sklearn.linear_model import LogisticRegression
#
# # Create an instance of the class
# LR = LogisticRegression(penalty='12', c = 10.0)
#
# # Fit the instance on the data and then predict the expected value
# LR = LR.fit(X_train, y_train)
# y_predict = LR.predict(X_test)
#
# # Can now view the output fitted coefficients
# LR.coef_
#
# # Tune regularization parameters with corss-validation
#
# LogisticRegressionCV
# ```
# ---
#
# ### Classification with logistic Regression
#
# **Aplications for Logistic Regression**:
# - Customer spending: How likely is a customer is to be a top 5% spender, using previous purchase data
#
# - Customer engegement: Which customers are most likely to engange in the next 6 months.
#
# - e-commerce: Which transactions are fraudulent, using customer characteristics, location, IP address, etc.
#
# - Finance/risk: Predicinting whether a loan will default.
#
# **Interpretation vs. prediction**
#
# - In addition to prediction, we may want to evaluate the importance of each factor in influencing outcomes.
#
# ---
# ### Classification Error Metrics
#
# > - Types of errors made in classification problems
# > - Approaches to measuring Classification outcomes
# > - Using classification error metrics to choose between models.
#
# ### Choosing the right error Measurement
#
# You are asked to build a classifier to predict whether individuals have leukemia.
#
# **Training data**:
# - 1 % patients have leukemia, 99% are healthy
#
# **Measure accuracy**:
# - Total % of predictions that are correct.
#
# build a simple model that always predicts "health".
#
# Accuracy will be .. 99%
#
# ### Confusion Matrix
#
#
# ![image-13.png](attachment:image-13.png)
#
# ### Accuracy: Predicting correctly
#
# ![image-14.png](attachment:image-14.png)
#
# ### Recall: Indentifying all positive instances
#
# ![image-15.png](attachment:image-15.png)
#
# ### Precision: Indentifying only positive instances
#
# ![image-16.png](attachment:image-16.png)
#
# ### Especificity: Avoiding False Alarms
#
# ![image-17.png](attachment:image-17.png)
#
# ### Error Measurements
#
# ![image-18.png](attachment:image-18.png)
#
# ---
#
# ### Classifications Error Metrics: ROC and Precision-Recall Curves
#
# ### Receiver Operating Characteristic (ROC)
#
# ![image-19.png](attachment:image-19.png)
#
# ![image-20.png](attachment:image-20.png)
#
# ### Precision-Recall Curve
#
# ![image-21.png](attachment:image-21.png)
#
# ### Choosing the right approach
#
# Which approach works best for choosing a classifier?
#
# **ROC Curve**
# - Generally better for data with balanced classes.
#
# **Precision-Recall Curve**
# - Generally better for data with imbalanced classes.
#
# The right curve depends on tying results (true positives, true negatives, etc.) to outcomes (relative cost of false positive or false negative)
#
# The curves compare classifiers generally (across possible decision thresholds), which may be less relevant to business objectives.
#
# ### Multiple class Error Metrics
#
# Most **multi-class error metrics** are similar to binary versions, they just expand elements as a sum.
#
# ![image-22.png](attachment:image-22.png)
#
# ### syntax
#
#
# ```python
# # Import the desired error function
# from sklearn.metrics import accuracy_score
#
# # calculate the error on the test and predicted data sets
# accuracy_value = accuracy_score(y_test, y_pred)
#
# # lots of other error metrics and diagnostic tools:
# from sklearn.metrics import precision_score, recall_score, f1_score
# roc_auc_score, confusion_matrix, roc_curve, precision_recall_curve.
# ```
