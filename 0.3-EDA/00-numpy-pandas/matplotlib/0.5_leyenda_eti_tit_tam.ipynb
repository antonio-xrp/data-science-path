# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## **Leyendas, etiquetas, títulos, tamaño**
#
# Para dar contexto a nuestros gráficos necesitamos usar títulos, leyendas, tamaño o etiquetas, para que nuestra gráfica tenga un contexto más amplio.
#
# **Cómo dar contexto a los gráficos**
#
# * Creamos nuestras gráficas comunes

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y,"b")
ax2.plot(y,x,"r");

# %% [markdown]
# **Contexto a los gráficos con títulos**
#
# Para crear los títulos realiza lo siguiente:

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
ax1.plot(x,y,"b")
ax1.set_title("Relacion x-y") # set_title to put a title

ax2.plot(y,x,"r")
ax2.set_title("Relacion y-x")
# Out:
# Text(0.5, 1.0, 'Relacion y-x')

# %% [markdown]
# **Contexto agregando etiquetas**
#
# * Agrega labels en los ejes

# %%
fig,(ax1,ax2)=plt.subplots(1,2)

ax1.plot(x,y,"b")
ax1.set_title("Relacion x-y")   
ax1.set_xlabel("x") # set_xlabel to put a label
ax1.set_ylabel("y") # set_ylabel to put a label

ax2.plot(y,x,"r")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("Relacion y-x")
# Out:
# Text(0.5, 1.0, 'Relacion y-x')

# %% [markdown]
# **Cambiar el tamaño a las figuras**
#
# Realiza la siguiente acción:

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(1,10)) # figsize to set the size of the figure

# %% [markdown]
# **Aplicar etiquetas (por defecto pone la mejor opción)**

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
ax1.plot(x,y,"b", label="six(x)") # label to put a label
ax1.set_title("Relacion x-y")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.legend(loc="upper center") # legend to put the label in the plot, loc to set the location there are several options like upper center, lower center, upper right, lower right, etc.

# %% [markdown]
# **Otras ubicaciones**
#
# | Upper Right  | Upper Left  | Lower Left  | Lower Right | Right       |
# | ------------ | ----------- | ----------- | ----------- | ----------- |
